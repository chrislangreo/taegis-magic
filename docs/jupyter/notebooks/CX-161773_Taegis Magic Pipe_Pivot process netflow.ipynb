# %% [markdown]
# # Setup

# %% [markdown]
# Change `/workspaces/taegis-sdk-python-workspace/taegis-magic` to wherever your taegis-magic dir is and make sure that is on the correct branch.<br><br>
# After changing the directory make sure to reload the kernel!

# %%
# !pip install -e /Users/chris.langreo/dev/taegis/taegis-magic-dir/taegis-magic

# %% [markdown]
# Installing itables for the purposes of displaying DataFrames in a nicer format

# %%
# !pip install itables

# %%
from taegis_magic.pandas.process import process_pivot_netflow
import pandas as pd
from itables import show

# %%
# %load_ext taegis_magic

# %%
# %taegis auth login --use-universal-authentication

# %% [markdown]
# Query to create aggregate process data

# %%
# %%taegis events search --assign agg_process_events
# from process
# EARLIEST=-1d
# | aggregate count by sensor_type, host_id, sensor_id, sensor_tenant, tenant_id
# | head 5

# %%
show(agg_process_events)

# %% [markdown]
# # Beginning of Testing

# %% [markdown]
# Setting log level to DEBUG to show more detail if desired

# %%
# import logging
# logging.basicConfig(level=logging.DEBUG)
# logging.getLogger("taegis_magic").setLevel(logging.DEBUG)

# %%
# Constants for calling pipe functions

region="charlie"
tenant_id="11063"

# %% [markdown]
# ## Empty DataFrame as input

# %% [markdown]
# For an empty DataFrame as input it should just be returned back

# %%
from pandas import DataFrame
empty_df = DataFrame()

ret_df = empty_df.pipe(process_pivot_netflow, region=region, tenant_id=tenant_id)
print(ret_df)

# %% [markdown]
# ## All columns in DataFrame are valid

# %% [markdown]
# All columns in input DataFrame are part of the `NETFLOW_PIVOT_COLUMNS` column

# %%
from taegis_magic.pandas.process import NETFLOW_PIVOT_COLUMNS
print(NETFLOW_PIVOT_COLUMNS)

# %%
ret_df = agg_process_events.pipe(process_pivot_netflow, region=region, tenant_id=tenant_id)
show(ret_df)

# %% [markdown]
# ## No columns in DataFrame are valid

# %% [markdown]
# Will reduce `process_events` DataFrame down to 1 column and will rename it so that the name of the column is not in `NETFLOW_PIVOT_COLUMNS`

# %%
process_events_no_valid_columns = agg_process_events[['host_id']].copy()
process_events_no_valid_columns.rename(columns={'host_id':'my_host_id'}, inplace=True)

process_events_no_valid_columns.pipe(process_pivot_netflow, region=region, tenant_id=tenant_id)

# %% [markdown]
# ## Mix of valid and invalid columns in DataFrame

# %% [markdown]
# Will reduce `process_events` DataFrame down to 2 columns and will rename just one of them so that one column will be part of the query and the other will not.

# %%
process_events_mixed_columns = agg_process_events[['host_id', 'sensor_type']].copy()
process_events_mixed_columns.rename(columns={'sensor_type':'my_sensor_type'}, inplace=True)
show(process_events_mixed_columns.pipe(process_pivot_netflow, region=region, tenant_id=tenant_id))

# %% [markdown]
# ## DataFrame that contains valid columns, but no data will be returned from query

# %% [markdown]
# The columns of the DataFrame will be valid, but the data will be made invalid by appending a string to each cell in the DataFrame. Therefore the input DataFrame, with invalid data, will be returned.

# %%
process_events_invalid_data = agg_process_events.apply(lambda col: col.astype(str) + 'a')
ret = process_events_invalid_data.pipe(process_pivot_netflow, region=region, tenant_id=tenant_id)
show(ret)
# Out:
# Input field `saveToCache` is deprecated: 'Moving to backendStrategy as an exclusion option'
# Input field `searchTarget` is deprecated: 'Moved to backendStrategy; ignored'
# Output field `backend` is deprecated: 'Moved to backendSource', removing from default output...
# Output field `name` is deprecated: 'name is deprecated. Use `userID` instead.', removing from default output...
# Output field `backend` is deprecated: 'Moved to backendSource', removing from default output...
# Hello!
# FROM netflow
# WHERE
#     (host_id = 'f1279c39-da11-59f5-9843-5d85e5edb84aa' AND sensor_id = 'f1279c39-da11-59f5-9843-5d85e5edb84aa' AND sensor_tenant = '11063a' AND sensor_type = 'ENDPOINT_TAEGISa' AND tenant_id = '11063a') or (host_id = '302c8cb3-7ae4-5264-907e-6716ce554652a' AND sensor_id = '302c8cb3-7ae4-5264-907e-6716ce554652a' AND sensor_tenant = '11063a' AND sensor_type = 'ENDPOINT_TAEGISa' AND tenant_id = '11063a') or (host_id = 'ab7bf22be4c617319c9ffbafbd41f868a' AND sensor_id = 'ab7bf22be4c617319c9ffbafbd41f868a' AND sensor_tenant = '0cba1339a' AND sensor_type = 'ENDPOINT_REDCLOAKa' AND tenant_id = '11063a') or (host_id = 'b549a3cc9018e1e93459146e24e1300ca' AND sensor_id = 'b549a3cc9018e1e93459146e24e1300ca' AND sensor_tenant = '0cba1339a' AND sensor_type = 'ENDPOINT_REDCLOAKa' AND tenant_id = '11063a') or (host_id = '602230c44ba4309a6715719e3a66bc7aa' AND sensor_id = '602230c44ba4309a6715719e3a66bc7aa' AND sensor_tenant = '0cba1339a' AND sensor_type = 'ENDPOINT_REDCLOAKa' AND tenant_id = '11063a')
# EARLIEST=-1d
# <!--| quarto-html-table-processing: none -->
# <table id="itables_98d1edad_8cdd_4126_bec3_b23862afa7bb">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.7.1 from the internet...
#         (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_98d1edad_8cdd_4126_bec3_b23862afa7bb:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"Truea\", \"f1279c39-da11-59f5-9843-5d85e5edb84aa\", \"ClauPCa\", \"2045a\", \"f1279c39-da11-59f5-9843-5d85e5edb84aa\", \"11063a\", \"ENDPOINT_TAEGISa\", \"11063a\"], [\"Truea\", \"302c8cb3-7ae4-5264-907e-6716ce554652a\", \"Win11June23a\", \"1731a\", \"302c8cb3-7ae4-5264-907e-6716ce554652a\", \"11063a\", \"ENDPOINT_TAEGISa\", \"11063a\"], [\"Truea\", \"ab7bf22be4c617319c9ffbafbd41f868a\", \"Nonea\", \"1a\", \"ab7bf22be4c617319c9ffbafbd41f868a\", \"0cba1339a\", \"ENDPOINT_REDCLOAKa\", \"11063a\"], [\"Truea\", \"b549a3cc9018e1e93459146e24e1300ca\", \"Nonea\", \"1a\", \"b549a3cc9018e1e93459146e24e1300ca\", \"0cba1339a\", \"ENDPOINT_REDCLOAKa\", \"11063a\"], [\"Truea\", \"602230c44ba4309a6715719e3a66bc7aa\", \"Nonea\", \"1a\", \"602230c44ba4309a6715719e3a66bc7aa\", \"0cba1339a\", \"ENDPOINT_REDCLOAKa\", \"11063a\"]]",
#           "layout": {"bottomEnd": null, "bottomStart": null, "topEnd": null, "topStart": null},
#           "order": [],
#           "style": {"caption-side": "bottom", "margin": "auto", "table-layout": "auto", "width": "auto"},
#           "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>enrichedHostnames</th>\n      <th>host_id</th>\n      <th>hostname</th>\n      <th>row_count</th>\n      <th>sensor_id</th>\n      <th>sensor_tenant</th>\n      <th>sensor_type</th>\n      <th>tenant_id</th>\n    </tr>\n  </thead></table>",
#           "text_in_header_can_be_selected": true
#         };
#         new ITable(table, dt_args);
#     });
# </script>
